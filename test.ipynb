# %%
from itchat_helper import ICHelper

ith = ICHelper()
# Out:
# █
# /Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
ith.login()
# Out:
# Getting uuid of QR code.
# ...
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as 玥男😖
# Traceback (most recent call last):
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/components/login.py", line 255, in maintain_loop
#     msgList = produce_msg(self, msgList)
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/components/messages.py", line 64, in produce_msg
#     utils.msg_formatter(m, 'Content')
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/utils.py", line 69, in msg_formatter
#     d[k]  = htmlParser.unescape(d[k])
# AttributeError: 'HTMLParser' object has no attribute 'unescape'
#
# Traceback (most recent call last):
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/components/login.py", line 255, in maintain_loop
# ...

# %%
ith.get_chatrooms()
# Out:
# [{'nickname': '门兴格拉德巴赫', 'username': '@@bba4cdf8d9441f5f4c733ad728e1fc9017b86ed0af3fce3d4b3cbc4b3ac54adc'}, {'nickname': '怀旧-皇家马德里', 'username': '@@ff9b345b6bb6099f3b3ce4c6336547080c9b4e02ede426c5fb86acfb51ffc5fe'}, {'nickname': '前端技术交流群11', 'username': '@@7c9d585d48280c7223bf295e995e7a864b483c2ad0632821678b6c8d3309194e'}, {'nickname': '自由足球Alpha_Team', 'username': '@@e4533153409ae1a6977f77444d95a3cefb0fbd08dc835943090a7ddb77a408a3'}, {'nickname': '玥男😖,空中飞人', 'username': '@@802614f72a31e9b5c76077179c49c5a8a49fdb111cfaeb41a4ded6f477288fb1'}, {'nickname': '开心苏宅', 'username': '@@433f6900160a9f7f2b66cd1948dc4758838c1c11e1fb5cccb7e9890b0a104cef'}, {'nickname': 'smite欧服欢乐群', 'username': '@@180d4c99b6610450b3fefa42452cb15abd733e85fd5fc896fd95bfd177f21040'}, {'nickname': '苏宅日常', 'username': '@@e1e1bbb071c202c0f4cd825cf4736b5ffbcd745ec95c82709481557e4ccd8287'}, {'nickname': '香港Ph.D-2024Fall', 'username': '@@3ba2f3ee2c7908e869ae9cf18be8e4cad46122ca26b170f91b7b752f77948dd0'}, {'nickname': 'Memo
# ...

# %%
ith.send_chatroom_msg("= =","怀旧-皇家马德里")
# Out:
# True

# %%
# 退出登录
# itchat.logout()
