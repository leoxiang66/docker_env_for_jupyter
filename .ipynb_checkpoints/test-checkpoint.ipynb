# %%
import itchat

# 登录
# itchat.auto_login(enableCmdQR=True,hotReload=True)
itchat.auto_login(picDir='qrcode.png')

# 获取所有群组
chatrooms = itchat.get_chatrooms()

# 输出群组信息
for chatroom in chatrooms:
    print("群名称:", chatroom['NickName'])
    print("群ID:", chatroom['UserName'])
    print("群成员数:", len(chatroom['MemberList']))
    print("群主:", chatroom['ChatRoomOwner'])
    print("-----")
# Out:
# Traceback (most recent call last):
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/components/login.py", line 255, in maintain_loop
#     msgList = produce_msg(self, msgList)
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/components/messages.py", line 62, in produce_msg
#     produce_group_chat(core, m)
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/components/messages.py", line 257, in produce_group_chat
#     utils.msg_formatter(msg, 'Content')
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/utils.py", line 69, in msg_formatter
#     d[k]  = htmlParser.unescape(d[k])
# AttributeError: 'HTMLParser' object has no attribute 'unescape'
#
# Traceback (most recent call last):
#   File "/Users/leon/git/docker_env_for_jupyter/venv/lib/python3.9/site-packages/itchat/components/login.py", line 255, in maintain_loop
# ...

# %%
import pprint as pp

# %%
pp.pprint(list(chatrooms))
# Out:
# [{'Alias': '',
#   'AppAccountFlag': 0,
#   'AttrStatus': 0,
#   'ChatRoomId': 0,
#   'City': '',
#   'ContactFlag': 2,
#   'DisplayName': '',
#   'EncryChatRoomId': '',
#   'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgetheadimg?seq=832246583&username=@@b706c23203295690248ceeaf5d217f914b89c3d4bdc9d890c070e10b82cd25ba&skey=@crypt_65e4a9ce_29741c1fdbbbe2223427e5388831c09a',
#   'HideInputBarFlag': 0,
#   'IsAdmin': None,
#   'IsOwner': 0,
#   'KeyWord': '',
#   'MemberCount': 102,
#   'MemberList': <ContactList: []>,
#   'NickName': '怀旧-皇家马德里',
#   'OwnerUin': 0,
#   'PYInitial': '',
#   'PYQuanPin': '',
#   'Province': '',
#   'RemarkName': '',
#   'RemarkPYInitial': '',
#   'RemarkPYQuanPin': '',
#   'Self': {'Alias': '',
#            'AppAccountFlag': 0,
#            'AttrStatus': 0,
#            'ChatRoomId': 0,
#            'City': '',
#            'ContactFlag': 0,
#            'DisplayName': '',
#            'EncryChatRoomId': '',
#            'HeadImgFlag': 1,
# ...

# %%
print(type(chatrooms))
# Out:
# <class 'itchat.storage.templates.ContactList'>

# %%
# Out:
# [<Chatroom: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@@b706c23203295690248ceeaf5d217f914b89c3d4bdc9d890c070e10b82cd25ba', 'NickName': '怀旧-皇家马德里', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgetheadimg?seq=832246583&username=@@b706c23203295690248ceeaf5d217f914b89c3d4bdc9d890c070e10b82cd25ba&skey=@crypt_65e4a9ce_29741c1fdbbbe2223427e5388831c09a', 'ContactFlag': 2, 'MemberCount': 102, 'RemarkName': '', 'HideInputBarFlag': 0, 'Sex': 0, 'Signature': '', 'VerifyFlag': 0, 'OwnerUin': 0, 'PYInitial': '', 'PYQuanPin': '', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'StarFriend': 0, 'AppAccountFlag': 0, 'Statues': 0, 'AttrStatus': 0, 'Province': '', 'City': '', 'Alias': '', 'SnsFlag': 0, 'UniFriend': 0, 'DisplayName': '', 'ChatRoomId': 0, 'KeyWord': '', 'EncryChatRoomId': '', 'IsOwner': 0, 'IsAdmin': None, 'Self': <User: {'MemberList': <ContactList: []>, 'UserName': '@94b9155e789a246d1e85e9127ea65e4a4cb2c0d78ae1e1022d088d6fb34b57ab', 'City': '', 'DisplayName': '', 'PYQuanPin': '
# ...

# %%
# 退出登录
# itchat.logout()
